# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../../data/EC_X_val_40.csv")
df
# Out:
#                ID                               SEQUENCE  NEW-CONCENTRATION  \
# 0    dbaasp_11356                FKRFKGSVKHGKGHLVHHIGVAL              0.301
# 1    dbaasp_13842                          GKLLSLLSLLGLL              1.398
# 2    dbaasp_19528                       AKVVNKLTKKVAKLLK              1.204
# 3     dbaasp_3675      GLLDGILNANFNAAKSAGTSVLNALSCKLSKTC              0.970
# 4     dbaasp_1472  GLFSVVTGVLKAVGKNVAKNVGGSLLEQLKCKISGGC              1.176
# ..            ...                                    ...                ...
# 606   dbaasp_5853                    GLLKKWLKKWKEFKRIVGY              1.124
# 607  dbaasp_18224                               PWKLSLHL              1.204
# 608  dbaasp_15878                             ALQYIKLLKE              2.000
# 609  dbaasp_12227                       FLGFVGQALNALLGKL              1.806
# 610   dbaasp_2205                          FLPIVTNLLSGLL              2.364
#
# ...

# %%
df.iloc[:,250:-12]
# Out:
#      Genome_A  Genome_C  Genome_G  Genome_T       AA        AC        AG  \
# 0    0.246193  0.254239  0.253668    0.2459  0.07282  0.055319  0.051278
# 1    0.246193  0.254239  0.253668    0.2459  0.07282  0.055319  0.051278
# 2    0.246193  0.254239  0.253668    0.2459  0.07282  0.055319  0.051278
# 3    0.246193  0.254239  0.253668    0.2459  0.07282  0.055319  0.051278
# 4    0.246193  0.254239  0.253668    0.2459  0.07282  0.055319  0.051278
# ..        ...       ...       ...       ...      ...       ...       ...
# 606  0.246193  0.254239  0.253668    0.2459  0.07282  0.055319  0.051278
# 607  0.246193  0.254239  0.253668    0.2459  0.07282  0.055319  0.051278
# 608  0.246193  0.254239  0.253668    0.2459  0.07282  0.055319  0.051278
# 609  0.246193  0.254239  0.253668    0.2459  0.07282  0.055319  0.051278
# 610  0.246193  0.254239  0.253668    0.2459  0.07282  0.055319  0.051278
#
#            AT        CA        CC  ...      TCG       TCT       TGA       TGC  \
# ...
